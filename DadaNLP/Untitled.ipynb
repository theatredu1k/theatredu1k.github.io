# %%
import random

import json
import secrets #hexadecimal generator
import requests # get url and data from JSON
import re #manipulate strings
import datetime
from nltk.tag import pos_tag
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3b37b19d6cde> in <module>()
#       2
#       3 import json
# ----> 4 import secrets #hexadecimal generator
#       5 import requests # get url and data from JSON
#       6 import re #manipulate strings
#
# ImportError: No module named secrets
