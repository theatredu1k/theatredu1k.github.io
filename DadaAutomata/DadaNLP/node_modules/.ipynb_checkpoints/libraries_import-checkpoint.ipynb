# %%
pwd
# Out:
# '/Users/macbookpro/Documents/theatredu1k.github.io/DadaNLP/node_modules'

# %%
# conda activate dataviz in terminal before launching jupyter notebook
import random
import json
import tracery #grammar generator
import secrets #hexadecimal generator
import requests # get url and data from JSON
import re #manipulate strings
import datetime
from nltk.tag import pos_tag # pip3 install --user -U nltk
